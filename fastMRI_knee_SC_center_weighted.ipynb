# %% [markdown]
# # fastMRI Knee Single Coil Baseline

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os, sys
sys.path.append('/content/drive/MyDrive/CS7643/fastMRI/')

# %%
# %cd /content/drive/MyDrive/CS7643/fastMRI/
# Out:
# /content/drive/.shortcut-targets-by-id/1dnCptuLSGqhIoTnU_kSvlh_TcxuGzVXU/fastMRI

# %%
# !head -100 fastmri/pl_modules/__init__.py
# Out:
# """
# Copyright (c) Facebook, Inc. and its affiliates.
#
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.
# """
#
# from .data_module import FastMriDataModule
# from .mri_module import MriModule
# from .unet_module import UnetModule
# from .varnet_module import VarNetModule
# from .unet_module_center_weighted_loss import UnetModuleCenterWeighted

# %%
# %cd /content/drive/MyDrive/fastMRI
# !pip install -r requirements.txt

# %% [markdown]
# ## Preparing Data

# %%
from train import unet_knee_sc_center_weighted_loss
# Out:
# /content/drive/.shortcut-targets-by-id/1dnCptuLSGqhIoTnU_kSvlh_TcxuGzVXU/fastMRI/fastmri/__init__.py:16: UserWarning: Could not retrieve fastmri version!
#   warnings.warn("Could not retrieve fastmri version!")

# %%
# %%writefile fastmri_dirs.yaml
# knee_path: /content/drive/MyDrive/CS7643_Project/data/train/extracted_files
# log_path: /content/drive/MyDrive/CS7643/fastMRI/logs
# Out:
# Overwriting fastmri_dirs.yaml

# %% [markdown]
# ## Train

# %%
unet_knee_sc_center_weighted_loss.run_cli()
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 42
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# ...

# %%
from fastmri.pl_modules.data_module import KneeDataModule
# Inspect data to ensure it is not empty
data_module = KneeDataModule(
    knee_path=knee_path,  # update path to where knee data is stored
    challenge='singlecoil',
    resolution=320,
)
len(data_module.train_dataset)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-54a99647caa1> in <cell line: 0>()
# ----> 1 from fastmri.pl_modules.data_module import KneeDataModule
#       2 # Inspect data to ensure it is not empty
#       3 data_module = KneeDataModule(
#       4     knee_path=knee_path,  # update path to where knee data is stored
#       5     challenge='singlecoil',
#
# ImportError: cannot import name 'KneeDataModule' from 'fastmri.pl_modules.data_module' (/content/drive/.shortcut-targets-by-id/1dnCptuLSGqhIoTnU_kSvlh_TcxuGzVXU/fastMRI/fastmri/pl_modules/data_module.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...
